# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
import matplotlib.pyplot as plt
import os
import csv
from datetime import datetime

# %%
def flatten(obs):
    return torch.tensor(obs.flatten(), dtype=torch.float32)

# %%
class PPO_Model(nn.Module):
    def __init__(self, input_dim=42, n_actions=7):
        super().__init__()
        self.shared = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
        )

        self.policy = nn.Linear(128, n_actions)
        self.value = nn.Linear(128, 1)

    def forward(self, x):
        x = self.shared(x)
        return self.policy(x), self.value(x)

    def act(self, obs, available_actions=None):
        logits, value = self.forward(obs)
        
        # Mask illegal actions
        if available_actions is not None:
            mask = torch.ones(logits.size(-1)) * float('-inf')
            mask[available_actions] = 0
            logits = logits + mask
        
        probs = torch.softmax(logits, dim=-1)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample()
        return action.item(), dist.log_prob(action), value

# %%
class SelfPlayOpponent:
    """
    Stores older snapshots of the agent and samples from them.
    If empty, plays random.
    """
    def __init__(self):
        self.opponents = []

    def add(self, model_state):
        self.opponents.append(model_state)

    def select_action(self, obs, model_class):
        if len(self.opponents) == 0:
            # Random if no opponent yet
            legal = [i for i in range(7) if obs[0, i] == 0]
            return np.random.choice(legal)

        # Sample a random past model
        snapshot = np.random.choice(self.opponents)
        opponent_model = model_class()
        opponent_model.load_state_dict(snapshot)
        opponent_model.eval()

        obs_flat = flatten(obs)
        logits, _ = opponent_model(obs_flat)
        probs = torch.softmax(logits, dim=-1)
        action = torch.argmax(probs).item()

        # Ensure legal
        legal = [i for i in range(7) if obs[0, i] == 0]
        if action not in legal:
            action = np.random.choice(legal)
        return action

# %%
class Connect4Env:
    def __init__(self, opponent=None):
        self.rows, self.cols = 6, 7
        self.opponent = opponent  
        self.reset()

    def reset(self):
        self.board = np.zeros((self.rows, self.cols), dtype=np.int8)
        self.done = False
        return self.board.copy()

    def available_actions(self):
        return [c for c in range(self.cols) if self.board[0, c] == 0]

    def drop(self, col, player):
        if self.board[0, col] != 0:
            return False
        for r in range(self.rows - 1, -1, -1):
            if self.board[r, col] == 0:
                self.board[r, col] = player
                return True
        return False

    def check_win(self, p):
        b = self.board
        R, C = self.rows, self.cols

        # Horizontal
        for r in range(R):
            for c in range(C - 3):
                if np.all(b[r, c:c + 4] == p):
                    return True

        # Vertical
        for r in range(R - 3):
            for c in range(C):
                if np.all(b[r:r + 4, c] == p):
                    return True

        # Diagonal down-right
        for r in range(R - 3):
            for c in range(C - 3):
                if all(b[r + i, c + i] == p for i in range(4)):
                    return True

        # Diagonal up-right
        for r in range(3, R):
            for c in range(C - 3):
                if all(b[r - i, c + i] == p for i in range(4)):
                    return True

        return False

    def is_draw(self):
        return np.all(self.board != 0)

    def three_in_row(self, p):
        b = self.board
        R, C = self.rows, self.cols
        count = 0

        for r in range(R):
            for c in range(C - 2):
                if np.sum(b[r, c:c+3] == p) == 3:
                    count += 1

        for r in range(R - 2):
            for c in range(C):
                if np.sum(b[r:r+3, c] == p) == 3:
                    count += 1

        for r in range(R - 2):
            for c in range(C - 2):
                if all(b[r + i, c + i] == p for i in range(3)):
                    count += 1

        for r in range(2, R):
            for c in range(C - 2):
                if all(b[r - i, c + i] == p for i in range(3)):
                    count += 1

        return count

    def step(self, action):
        # ----- Agent Move -----
        # Check legality first
        if action not in self.available_actions():
            # Illegal move: penalize and retry (do not end episode, do not let opponent play)
            return self.board.copy(), -0.5, False, {"illegal": True}

        self.drop(action, 1)

        # Shaping: 3-in-a-row
        reward = 0.1 * self.three_in_row(1)
        reward -= 0.1 * self.three_in_row(2)

        # Win?
        if self.check_win(1):
            return self.board.copy(), reward + 1.0, True, {"winner": 1}

        # Draw?
        if self.is_draw():
            return self.board.copy(), reward, True, {"winner": 0}

        # ----- Opponent Move -----
        if self.opponent:
            if isinstance(self.opponent, SelfPlayOpponent):
                opp_action = self.opponent.select_action(self.board.copy(), PPO_Model)
            else:
                # Fallback random
                avail = self.available_actions()
                if not avail: # Should be covered by is_draw, but safety check
                     return self.board.copy(), reward, True, {"winner": 0}
                opp_action = np.random.choice(avail)

            self.drop(opp_action, 2)

            # Opponent shaping
            reward -= 0.1 * self.three_in_row(2)

            # Loss?
            if self.check_win(2):
                return self.board.copy(), reward - 1.0, True, {"winner": 2}

            # Draw?
            if self.is_draw():
                return self.board.copy(), reward, True, {"winner": 0}

        return self.board.copy(), reward, False, {}

# %%
gamma = 0.99
lam = 0.95
ppo_epochs = 4
clip_eps = 0.2
batch_size = 64
lr = 3e-4
entropy_coef = 0.05  # Increase for exploration

# %%
def save_checkpoint(model, ep):
    filename = os.path.join(run_dir, f"checkpoint_ep{ep}.pth")
    torch.save(model.state_dict(), filename)
    print(f" Saved checkpoint: {filename}")

def save_best_model(model):
    torch.save(model.state_dict(), BEST_MODEL)
    print(f" New best model saved to {BEST_MODEL}")

def log_to_csv(ep, reward, avg10, best):
    with open(LOG_FILE, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([ep, reward, avg10, best])

# %%
def compute_gae(rewards, values, dones):
    advantages, gae = [], 0
    
    # Convert all values to detached tensors
    values = [v.detach().item() if hasattr(v, 'detach') else float(v) for v in values]
    values = values + [0.0]

    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t+1] * (1-dones[t]) - values[t]
        gae = delta + gamma * lam * (1-dones[t]) * gae
        advantages.insert(0, gae)
    
    returns = [adv + values[i] for i, adv in enumerate(advantages)]
    
    # Convert back to tensors
    return [torch.tensor(a, dtype=torch.float32) for a in advantages], \
           [torch.tensor(r, dtype=torch.float32) for r in returns]

# %%
reward_history = [] 
best_avg_reward = -99999

model = PPO_Model()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
def train_connect4_selfplay(episodes=500, log_interval=10):

    from datetime import datetime
    run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
    log_dir = os.path.join("runs", f"connect4_{run_id}")
    os.makedirs(log_dir, exist_ok=True)
    log_file_path = os.path.join(log_dir, "training_log.csv")

    with open(log_file_path, "w") as f:
        f.write("episode,total_reward,avg_reward_10,best_reward\n")


    opponent_manager = SelfPlayOpponent()
    env = Connect4Env(opponent=opponent_manager)

    reward_history = []
    best_avg_reward = -float("inf")

    for ep in range(episodes):

        obs = env.reset()
        done = False
        ep_reward = 0

        states, actions, logprobs, vals, rewards, dones = [], [], [], [], [], []

        # ====== RUN ONE EPISODE ======
        while not done:
            s = flatten(obs).detach()
            a, lp, v = model.act(s)

            states.append(s)
            actions.append(a)
            logprobs.append(lp.detach())
            vals.append(v.detach())

            obs, r, done, info = env.step(a)
            rewards.append(r)
            dones.append(done)

            ep_reward += r

        adv, ret = compute_gae(rewards, vals, dones)
        adv = torch.stack(adv).detach()
        ret = torch.stack(ret).detach()
        adv = (adv - adv.mean()) / (adv.std() + 1e-8)

        states = torch.stack(states).detach()
        actions = torch.tensor(actions)
        logprobs_old = torch.stack(logprobs).detach()

        # ====== PPO UPDATE ======
        for _ in range(ppo_epochs):
            logits, value = model(states)
            probs = torch.softmax(logits, dim=-1)
            dist = torch.distributions.Categorical(probs)

            new_logprobs = dist.log_prob(actions)
            ratio = (new_logprobs - logprobs_old).exp()

            s1 = ratio * adv
            s2 = torch.clamp(ratio, 1 - clip_eps, 1 + clip_eps) * adv
            policy_loss = -torch.min(s1, s2).mean()

            value_loss = torch.nn.functional.mse_loss(value.squeeze(), ret)
            entropy = dist.entropy().mean()

            loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # ====== LOGGING ======
        reward_history.append(ep_reward)
        avg10 = np.mean(reward_history[-10:])

        print(f"Episode {ep+1}: Reward={ep_reward:.2f}, Avg10={avg10:.2f}")

        with open(log_file_path, "a") as f:
            f.write(f"{ep+1},{ep_reward},{avg10},{best_avg_reward}\n")

        # ====== SAVE BEST MODEL ======
        if avg10 > best_avg_reward:
            best_avg_reward = avg10
            save_path = os.path.join(log_dir, "best_model.pth")
            torch.save(model.state_dict(), save_path)

            # Save snapshot for self-play
            opponent_manager.add(model.state_dict())
            print("New best model saved + added to Self-play pool!")

        if (ep+1) % log_interval == 0:
            ckpt = os.path.join(log_dir, f"checkpoint_ep{ep+1}.pth")
            torch.save(model.state_dict(), ckpt)
            print(f" Saved checkpoint {ckpt}")
    
    return reward_history, best_avg_reward

# %%
reward_history,best_avg_reward=train_connect4_selfplay(episodes=1000, log_interval=100)
# Out:
# Episode 1: Reward=-2.00, Avg10=-2.00
# New best model saved + added to Self-play pool!
# Episode 2: Reward=2.10, Avg10=0.05
# New best model saved + added to Self-play pool!
# Episode 3: Reward=-1.40, Avg10=-0.43
# Episode 4: Reward=-1.10, Avg10=-0.60
# Episode 5: Reward=-2.30, Avg10=-0.94
# Episode 6: Reward=-1.40, Avg10=-1.02
# Episode 7: Reward=-1.40, Avg10=-1.07
# Episode 8: Reward=-1.40, Avg10=-1.11
# Episode 9: Reward=-2.20, Avg10=-1.23
# Episode 10: Reward=-1.40, Avg10=-1.25
# Episode 11: Reward=0.50, Avg10=-1.00
# Episode 12: Reward=-4.30, Avg10=-1.64
# Episode 13: Reward=-1.30, Avg10=-1.63
# Episode 14: Reward=-6.20, Avg10=-2.14
# Episode 15: Reward=-1.10, Avg10=-2.02
# Episode 16: Reward=-1.20, Avg10=-2.00
# Episode 17: Reward=-1.00, Avg10=-1.96
# Episode 18: Reward=-1.40, Avg10=-1.96
# Episode 19: Reward=1.20, Avg10=-1.62
# Episode 20: Reward=-1.50, Avg10=-1.63
# Episode 21: Reward=-3.40, Avg10=-2.02
# Episode 22: Reward=1.30, Avg10=-1.46
# Episode 23: Reward=1.30, Avg10=-1.20
# Episode 24: Reward=-3.10, Avg10=-0.89
# Episode 25: Reward=-1.40, Avg10=-0.92
# Episode 26: Reward=-1.40, Avg10=-0.94
# Episode 27: Reward=-1.40, Avg10=-0.98
# Episode 28: Reward=-2.10, Avg10=-1.05
# Episode 29: Reward=-1.60, Avg10=-1.33
# Episode 30: Reward=-1.40, Avg10=-1.32
# Episode 31: Reward=-1.30, Avg10=-1.11
# Episode 32: Reward=-2.10, Avg10=-1.45
# Episode 33: Reward=-1.00, Avg10=-1.68
# Episode 34: Reward=-1.40, Avg10=-1.51
# Episode 35: Reward=-1.40, Avg10=-1.51
# Episode 36: Reward=-0.90, Avg10=-1.46
# Episode 37: Reward=-1.30, Avg10=-1.45
# Episode 38: Reward=-1.30, Avg10=-1.37
# Episode 39: Reward=0.70, Avg10=-1.14
# Episode 40: Reward=-1.60, Avg10=-1.16
# Episode 41: Reward=-1.40, Avg10=-1.17
# Episode 42: Reward=-1.40, Avg10=-1.10
# Episode 43: Reward=-1.40, Avg10=-1.14
# Episode 44: Reward=-1.40, Avg10=-1.14
# Episode 45: Reward=1.30, Avg10=-0.87
# Episode 46: Reward=-0.10, Avg10=-0.79
# Episode 47: Reward=-1.20, Avg10=-0.78
# Episode 48: Reward=-2.10, Avg10=-0.86
# Episode 49: Reward=-1.30, Avg10=-1.06
# Episode 50: Reward=-1.20, Avg10=-1.02
# Episode 51: Reward=-1.40, Avg10=-1.02
# Episode 52: Reward=-1.40, Avg10=-1.02
# Episode 53: Reward=0.30, Avg10=-0.85
# Episode 54: Reward=-1.40, Avg10=-0.85
# Episode 55: Reward=-1.20, Avg10=-1.10
# Episode 56: Reward=-1.30, Avg10=-1.22
# Episode 57: Reward=-3.30, Avg10=-1.43
# Episode 58: Reward=-1.40, Avg10=-1.36
# Episode 59: Reward=-1.10, Avg10=-1.34
# Episode 60: Reward=0.30, Avg10=-1.19
# Episode 61: Reward=-1.40, Avg10=-1.19
# Episode 62: Reward=1.30, Avg10=-0.92
# Episode 63: Reward=0.80, Avg10=-0.87
# Episode 64: Reward=-1.30, Avg10=-0.86
# Episode 65: Reward=-3.00, Avg10=-1.04
# Episode 66: Reward=-1.80, Avg10=-1.09
# Episode 67: Reward=-1.10, Avg10=-0.87
# Episode 68: Reward=-2.70, Avg10=-1.00
# Episode 69: Reward=-1.40, Avg10=-1.03
# Episode 70: Reward=0.20, Avg10=-1.04
# Episode 71: Reward=0.90, Avg10=-0.81
# Episode 72: Reward=-1.40, Avg10=-1.08
# Episode 73: Reward=-3.90, Avg10=-1.55
# Episode 74: Reward=-1.60, Avg10=-1.58
# Episode 75: Reward=1.30, Avg10=-1.15
# Episode 76: Reward=-2.50, Avg10=-1.22
# Episode 77: Reward=-1.00, Avg10=-1.21
# Episode 78: Reward=-3.70, Avg10=-1.31
# Episode 79: Reward=-2.70, Avg10=-1.44
# Episode 80: Reward=-0.10, Avg10=-1.47
# Episode 81: Reward=-1.30, Avg10=-1.69
# Episode 82: Reward=-5.80, Avg10=-2.13
# Episode 83: Reward=-1.20, Avg10=-1.86
# Episode 84: Reward=-7.00, Avg10=-2.40
# Episode 85: Reward=0.20, Avg10=-2.51
# Episode 86: Reward=-3.50, Avg10=-2.61
# Episode 87: Reward=0.00, Avg10=-2.51
# Episode 88: Reward=-3.70, Avg10=-2.51
# Episode 89: Reward=-1.00, Avg10=-2.34
# Episode 90: Reward=0.60, Avg10=-2.27
# Episode 91: Reward=-1.60, Avg10=-2.30
# Episode 92: Reward=1.80, Avg10=-1.54
# Episode 93: Reward=-1.90, Avg10=-1.61
# Episode 94: Reward=1.70, Avg10=-0.74
# Episode 95: Reward=-0.10, Avg10=-0.77
# Episode 96: Reward=1.50, Avg10=-0.27
# Episode 97: Reward=1.40, Avg10=-0.13
# Episode 98: Reward=-3.60, Avg10=-0.12
# Episode 99: Reward=-1.10, Avg10=-0.13
# Episode 100: Reward=-3.30, Avg10=-0.52
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep100.pth
# Episode 101: Reward=-1.20, Avg10=-0.48
# Episode 102: Reward=-2.20, Avg10=-0.88
# Episode 103: Reward=-1.40, Avg10=-0.83
# Episode 104: Reward=2.20, Avg10=-0.78
# Episode 105: Reward=-1.60, Avg10=-0.93
# Episode 106: Reward=-0.80, Avg10=-1.16
# Episode 107: Reward=-1.30, Avg10=-1.43
# Episode 108: Reward=-2.70, Avg10=-1.34
# Episode 109: Reward=-1.40, Avg10=-1.37
# Episode 110: Reward=1.30, Avg10=-0.91
# Episode 111: Reward=0.80, Avg10=-0.71
# Episode 112: Reward=1.50, Avg10=-0.34
# Episode 113: Reward=-1.30, Avg10=-0.33
# Episode 114: Reward=-1.80, Avg10=-0.73
# Episode 115: Reward=-1.60, Avg10=-0.73
# Episode 116: Reward=0.90, Avg10=-0.56
# Episode 117: Reward=0.20, Avg10=-0.41
# Episode 118: Reward=-2.00, Avg10=-0.34
# Episode 119: Reward=1.00, Avg10=-0.10
# Episode 120: Reward=-1.30, Avg10=-0.36
# Episode 121: Reward=-2.30, Avg10=-0.67
# Episode 122: Reward=-6.20, Avg10=-1.44
# Episode 123: Reward=1.70, Avg10=-1.14
# Episode 124: Reward=-3.70, Avg10=-1.33
# Episode 125: Reward=0.50, Avg10=-1.12
# Episode 126: Reward=0.60, Avg10=-1.15
# Episode 127: Reward=-1.10, Avg10=-1.28
# Episode 128: Reward=-2.60, Avg10=-1.34
# Episode 129: Reward=1.50, Avg10=-1.29
# Episode 130: Reward=1.30, Avg10=-1.03
# Episode 131: Reward=-1.20, Avg10=-0.92
# Episode 132: Reward=1.30, Avg10=-0.17
# Episode 133: Reward=-0.60, Avg10=-0.40
# Episode 134: Reward=0.80, Avg10=0.05
# Episode 135: Reward=-2.00, Avg10=-0.20
# Episode 136: Reward=-2.40, Avg10=-0.50
# Episode 137: Reward=0.90, Avg10=-0.30
# Episode 138: Reward=0.40, Avg10=-0.00
# Episode 139: Reward=-0.80, Avg10=-0.23
# Episode 140: Reward=-0.70, Avg10=-0.43
# Episode 141: Reward=-0.60, Avg10=-0.37
# Episode 142: Reward=-0.80, Avg10=-0.58
# Episode 143: Reward=1.50, Avg10=-0.37
# Episode 144: Reward=-3.10, Avg10=-0.76
# Episode 145: Reward=-9.20, Avg10=-1.48
# Episode 146: Reward=-1.50, Avg10=-1.39
# Episode 147: Reward=-3.20, Avg10=-1.80
# Episode 148: Reward=-4.10, Avg10=-2.25
# Episode 149: Reward=0.10, Avg10=-2.16
# Episode 150: Reward=-2.10, Avg10=-2.30
# Episode 151: Reward=-2.20, Avg10=-2.46
# Episode 152: Reward=0.90, Avg10=-2.29
# Episode 153: Reward=-1.60, Avg10=-2.60
# Episode 154: Reward=-1.90, Avg10=-2.48
# Episode 155: Reward=1.40, Avg10=-1.42
# Episode 156: Reward=-2.80, Avg10=-1.55
# Episode 157: Reward=0.90, Avg10=-1.14
# Episode 158: Reward=-1.60, Avg10=-0.89
# Episode 159: Reward=-2.30, Avg10=-1.13
# Episode 160: Reward=-2.40, Avg10=-1.16
# Episode 161: Reward=-1.30, Avg10=-1.07
# Episode 162: Reward=-1.40, Avg10=-1.30
# Episode 163: Reward=-1.40, Avg10=-1.28
# Episode 164: Reward=-3.30, Avg10=-1.42
# Episode 165: Reward=-1.90, Avg10=-1.75
# Episode 166: Reward=-1.50, Avg10=-1.62
# Episode 167: Reward=0.90, Avg10=-1.62
# Episode 168: Reward=-2.30, Avg10=-1.69
# Episode 169: Reward=0.50, Avg10=-1.41
# Episode 170: Reward=-5.30, Avg10=-1.70
# Episode 171: Reward=0.70, Avg10=-1.50
# Episode 172: Reward=1.90, Avg10=-1.17
# Episode 173: Reward=-4.00, Avg10=-1.43
# Episode 174: Reward=-1.20, Avg10=-1.22
# Episode 175: Reward=-1.60, Avg10=-1.19
# Episode 176: Reward=-3.20, Avg10=-1.36
# Episode 177: Reward=-2.20, Avg10=-1.67
# Episode 178: Reward=-6.50, Avg10=-2.09
# Episode 179: Reward=2.60, Avg10=-1.88
# Episode 180: Reward=-1.20, Avg10=-1.47
# Episode 181: Reward=1.30, Avg10=-1.41
# Episode 182: Reward=-2.30, Avg10=-1.83
# Episode 183: Reward=-0.20, Avg10=-1.45
# Episode 184: Reward=-9.00, Avg10=-2.23
# Episode 185: Reward=-2.00, Avg10=-2.27
# Episode 186: Reward=-2.20, Avg10=-2.17
# Episode 187: Reward=-2.10, Avg10=-2.16
# Episode 188: Reward=-2.70, Avg10=-1.78
# Episode 189: Reward=-0.30, Avg10=-2.07
# Episode 190: Reward=-5.50, Avg10=-2.50
# Episode 191: Reward=1.50, Avg10=-2.48
# Episode 192: Reward=-1.40, Avg10=-2.39
# Episode 193: Reward=1.30, Avg10=-2.24
# Episode 194: Reward=-1.40, Avg10=-1.48
# Episode 195: Reward=-1.40, Avg10=-1.42
# Episode 196: Reward=-1.70, Avg10=-1.37
# Episode 197: Reward=-1.40, Avg10=-1.30
# Episode 198: Reward=-0.70, Avg10=-1.10
# Episode 199: Reward=-1.60, Avg10=-1.23
# Episode 200: Reward=1.00, Avg10=-0.58
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep200.pth
# Episode 201: Reward=-2.20, Avg10=-0.95
# Episode 202: Reward=-1.30, Avg10=-0.94
# Episode 203: Reward=-1.30, Avg10=-1.20
# Episode 204: Reward=-5.90, Avg10=-1.65
# Episode 205: Reward=-0.80, Avg10=-1.59
# Episode 206: Reward=0.80, Avg10=-1.34
# Episode 207: Reward=-3.50, Avg10=-1.55
# Episode 208: Reward=-1.80, Avg10=-1.66
# Episode 209: Reward=1.20, Avg10=-1.38
# Episode 210: Reward=-1.20, Avg10=-1.60
# Episode 211: Reward=1.20, Avg10=-1.26
# Episode 212: Reward=0.50, Avg10=-1.08
# Episode 213: Reward=-1.70, Avg10=-1.12
# Episode 214: Reward=-1.30, Avg10=-0.66
# Episode 215: Reward=-2.30, Avg10=-0.81
# Episode 216: Reward=-1.40, Avg10=-1.03
# Episode 217: Reward=-8.40, Avg10=-1.52
# Episode 218: Reward=0.50, Avg10=-1.29
# Episode 219: Reward=-9.60, Avg10=-2.37
# Episode 220: Reward=-1.20, Avg10=-2.37
# Episode 221: Reward=-1.40, Avg10=-2.63
# Episode 222: Reward=-2.40, Avg10=-2.92
# Episode 223: Reward=-0.50, Avg10=-2.80
# Episode 224: Reward=-1.00, Avg10=-2.77
# Episode 225: Reward=-1.60, Avg10=-2.70
# Episode 226: Reward=-1.40, Avg10=-2.70
# Episode 227: Reward=1.00, Avg10=-1.76
# Episode 228: Reward=-11.20, Avg10=-2.93
# Episode 229: Reward=-1.30, Avg10=-2.10
# Episode 230: Reward=-1.60, Avg10=-2.14
# Episode 231: Reward=-3.10, Avg10=-2.31
# Episode 232: Reward=-1.80, Avg10=-2.25
# Episode 233: Reward=-1.70, Avg10=-2.37
# Episode 234: Reward=-1.80, Avg10=-2.45
# Episode 235: Reward=-1.00, Avg10=-2.39
# Episode 236: Reward=0.50, Avg10=-2.20
# Episode 237: Reward=-1.80, Avg10=-2.48
# Episode 238: Reward=-2.10, Avg10=-1.57
# Episode 239: Reward=-3.50, Avg10=-1.79
# Episode 240: Reward=-5.00, Avg10=-2.13
# Episode 241: Reward=0.60, Avg10=-1.76
# Episode 242: Reward=-6.90, Avg10=-2.27
# Episode 243: Reward=0.30, Avg10=-2.07
# Episode 244: Reward=1.10, Avg10=-1.78
# Episode 245: Reward=1.30, Avg10=-1.55
# Episode 246: Reward=1.00, Avg10=-1.50
# Episode 247: Reward=-4.00, Avg10=-1.72
# Episode 248: Reward=-1.40, Avg10=-1.65
# Episode 249: Reward=-2.80, Avg10=-1.58
# Episode 250: Reward=-1.40, Avg10=-1.22
# Episode 251: Reward=0.70, Avg10=-1.21
# Episode 252: Reward=0.60, Avg10=-0.46
# Episode 253: Reward=-4.70, Avg10=-0.96
# Episode 254: Reward=0.10, Avg10=-1.06
# Episode 255: Reward=-2.50, Avg10=-1.44
# Episode 256: Reward=-2.20, Avg10=-1.76
# Episode 257: Reward=0.20, Avg10=-1.34
# Episode 258: Reward=-0.80, Avg10=-1.28
# Episode 259: Reward=-1.20, Avg10=-1.12
# Episode 260: Reward=0.10, Avg10=-0.97
# Episode 261: Reward=0.20, Avg10=-1.02
# Episode 262: Reward=-2.50, Avg10=-1.33
# Episode 263: Reward=-3.70, Avg10=-1.23
# Episode 264: Reward=-1.40, Avg10=-1.38
# Episode 265: Reward=-1.30, Avg10=-1.26
# Episode 266: Reward=-1.10, Avg10=-1.15
# Episode 267: Reward=-1.10, Avg10=-1.28
# Episode 268: Reward=0.60, Avg10=-1.14
# Episode 269: Reward=-1.40, Avg10=-1.16
# Episode 270: Reward=0.20, Avg10=-1.15
# Episode 271: Reward=0.30, Avg10=-1.14
# Episode 272: Reward=-1.40, Avg10=-1.03
# Episode 273: Reward=-4.50, Avg10=-1.11
# Episode 274: Reward=-3.20, Avg10=-1.29
# Episode 275: Reward=0.30, Avg10=-1.13
# Episode 276: Reward=-1.50, Avg10=-1.17
# Episode 277: Reward=-1.40, Avg10=-1.20
# Episode 278: Reward=1.20, Avg10=-1.14
# Episode 279: Reward=-0.00, Avg10=-1.00
# Episode 280: Reward=1.10, Avg10=-0.91
# Episode 281: Reward=-1.30, Avg10=-1.07
# Episode 282: Reward=-1.40, Avg10=-1.07
# Episode 283: Reward=-1.40, Avg10=-0.76
# Episode 284: Reward=-1.30, Avg10=-0.57
# Episode 285: Reward=-1.40, Avg10=-0.74
# Episode 286: Reward=-1.40, Avg10=-0.73
# Episode 287: Reward=-1.30, Avg10=-0.72
# Episode 288: Reward=-1.40, Avg10=-0.98
# Episode 289: Reward=-1.40, Avg10=-1.12
# Episode 290: Reward=1.00, Avg10=-1.13
# Episode 291: Reward=-1.30, Avg10=-1.13
# Episode 292: Reward=-0.10, Avg10=-1.00
# Episode 293: Reward=-1.40, Avg10=-1.00
# Episode 294: Reward=-1.40, Avg10=-1.01
# Episode 295: Reward=-1.40, Avg10=-1.01
# Episode 296: Reward=-1.40, Avg10=-1.01
# Episode 297: Reward=-1.60, Avg10=-1.04
# Episode 298: Reward=-1.20, Avg10=-1.02
# Episode 299: Reward=-1.40, Avg10=-1.02
# Episode 300: Reward=-2.40, Avg10=-1.36
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep300.pth
# Episode 301: Reward=-1.30, Avg10=-1.36
# Episode 302: Reward=-1.30, Avg10=-1.48
# Episode 303: Reward=-1.40, Avg10=-1.48
# Episode 304: Reward=0.00, Avg10=-1.34
# Episode 305: Reward=1.00, Avg10=-1.10
# Episode 306: Reward=1.20, Avg10=-0.84
# Episode 307: Reward=-1.40, Avg10=-0.82
# Episode 308: Reward=-1.10, Avg10=-0.81
# Episode 309: Reward=1.10, Avg10=-0.56
# Episode 310: Reward=1.20, Avg10=-0.20
# Episode 311: Reward=-0.30, Avg10=-0.10
# Episode 312: Reward=-1.20, Avg10=-0.09
# Episode 313: Reward=0.30, Avg10=0.08
# New best model saved + added to Self-play pool!
# Episode 314: Reward=1.40, Avg10=0.22
# New best model saved + added to Self-play pool!
# Episode 315: Reward=-1.40, Avg10=-0.02
# Episode 316: Reward=-1.30, Avg10=-0.27
# Episode 317: Reward=-1.30, Avg10=-0.26
# Episode 318: Reward=0.90, Avg10=-0.06
# Episode 319: Reward=0.30, Avg10=-0.14
# Episode 320: Reward=-1.30, Avg10=-0.39
# Episode 321: Reward=-0.10, Avg10=-0.37
# Episode 322: Reward=-1.40, Avg10=-0.39
# Episode 323: Reward=-1.40, Avg10=-0.56
# Episode 324: Reward=-1.30, Avg10=-0.83
# Episode 325: Reward=-1.30, Avg10=-0.82
# Episode 326: Reward=-1.40, Avg10=-0.83
# Episode 327: Reward=-1.40, Avg10=-0.84
# Episode 328: Reward=-2.50, Avg10=-1.18
# Episode 329: Reward=-1.40, Avg10=-1.35
# Episode 330: Reward=-3.30, Avg10=-1.55
# Episode 331: Reward=-14.20, Avg10=-2.96
# Episode 332: Reward=-1.80, Avg10=-3.00
# Episode 333: Reward=-1.40, Avg10=-3.00
# Episode 334: Reward=0.10, Avg10=-2.86
# Episode 335: Reward=-1.40, Avg10=-2.87
# Episode 336: Reward=-1.40, Avg10=-2.87
# Episode 337: Reward=0.90, Avg10=-2.64
# Episode 338: Reward=1.00, Avg10=-2.29
# Episode 339: Reward=-1.40, Avg10=-2.29
# Episode 340: Reward=-3.10, Avg10=-2.27
# Episode 341: Reward=-1.40, Avg10=-0.99
# Episode 342: Reward=-0.50, Avg10=-0.86
# Episode 343: Reward=0.40, Avg10=-0.68
# Episode 344: Reward=-1.40, Avg10=-0.83
# Episode 345: Reward=0.70, Avg10=-0.62
# Episode 346: Reward=-1.40, Avg10=-0.62
# Episode 347: Reward=-1.40, Avg10=-0.85
# Episode 348: Reward=-1.40, Avg10=-1.09
# Episode 349: Reward=0.80, Avg10=-0.87
# Episode 350: Reward=-1.50, Avg10=-0.71
# Episode 351: Reward=1.20, Avg10=-0.45
# Episode 352: Reward=0.70, Avg10=-0.33
# Episode 353: Reward=0.90, Avg10=-0.28
# Episode 354: Reward=-3.50, Avg10=-0.49
# Episode 355: Reward=-1.40, Avg10=-0.70
# Episode 356: Reward=-2.40, Avg10=-0.80
# Episode 357: Reward=-1.30, Avg10=-0.79
# Episode 358: Reward=-1.30, Avg10=-0.78
# Episode 359: Reward=1.10, Avg10=-0.75
# Episode 360: Reward=0.80, Avg10=-0.52
# Episode 361: Reward=-1.80, Avg10=-0.82
# Episode 362: Reward=-0.70, Avg10=-0.96
# Episode 363: Reward=1.20, Avg10=-0.93
# Episode 364: Reward=-1.20, Avg10=-0.70
# Episode 365: Reward=-1.10, Avg10=-0.67
# Episode 366: Reward=1.20, Avg10=-0.31
# Episode 367: Reward=-1.60, Avg10=-0.34
# Episode 368: Reward=1.20, Avg10=-0.09
# Episode 369: Reward=-0.80, Avg10=-0.28
# Episode 370: Reward=-1.30, Avg10=-0.49
# Episode 371: Reward=1.30, Avg10=-0.18
# Episode 372: Reward=-1.60, Avg10=-0.27
# Episode 373: Reward=1.60, Avg10=-0.23
# Episode 374: Reward=1.20, Avg10=0.01
# Episode 375: Reward=-1.10, Avg10=0.01
# Episode 376: Reward=-0.80, Avg10=-0.19
# Episode 377: Reward=0.80, Avg10=0.05
# Episode 378: Reward=1.10, Avg10=0.04
# Episode 379: Reward=-1.60, Avg10=-0.04
# Episode 380: Reward=-1.40, Avg10=-0.05
# Episode 381: Reward=1.10, Avg10=-0.07
# Episode 382: Reward=1.10, Avg10=0.20
# Episode 383: Reward=-1.60, Avg10=-0.12
# Episode 384: Reward=-1.80, Avg10=-0.42
# Episode 385: Reward=0.60, Avg10=-0.25
# Episode 386: Reward=-1.30, Avg10=-0.30
# Episode 387: Reward=-1.20, Avg10=-0.50
# Episode 388: Reward=-1.20, Avg10=-0.73
# Episode 389: Reward=-1.60, Avg10=-0.73
# Episode 390: Reward=-1.60, Avg10=-0.75
# Episode 391: Reward=0.60, Avg10=-0.80
# Episode 392: Reward=0.80, Avg10=-0.83
# Episode 393: Reward=-1.50, Avg10=-0.82
# Episode 394: Reward=-1.40, Avg10=-0.78
# Episode 395: Reward=-1.30, Avg10=-0.97
# Episode 396: Reward=-1.60, Avg10=-1.00
# Episode 397: Reward=-1.40, Avg10=-1.02
# Episode 398: Reward=1.40, Avg10=-0.76
# Episode 399: Reward=0.70, Avg10=-0.53
# Episode 400: Reward=1.00, Avg10=-0.27
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep400.pth
# Episode 401: Reward=0.10, Avg10=-0.32
# Episode 402: Reward=-1.40, Avg10=-0.54
# Episode 403: Reward=-1.30, Avg10=-0.52
# Episode 404: Reward=-1.40, Avg10=-0.52
# Episode 405: Reward=-1.20, Avg10=-0.51
# Episode 406: Reward=1.00, Avg10=-0.25
# Episode 407: Reward=-1.40, Avg10=-0.25
# Episode 408: Reward=-1.60, Avg10=-0.55
# Episode 409: Reward=1.00, Avg10=-0.52
# Episode 410: Reward=-1.40, Avg10=-0.76
# Episode 411: Reward=-1.20, Avg10=-0.89
# Episode 412: Reward=-1.40, Avg10=-0.89
# Episode 413: Reward=1.00, Avg10=-0.66
# Episode 414: Reward=0.90, Avg10=-0.43
# Episode 415: Reward=-0.80, Avg10=-0.39
# Episode 416: Reward=1.10, Avg10=-0.38
# Episode 417: Reward=-1.40, Avg10=-0.38
# Episode 418: Reward=-2.70, Avg10=-0.49
# Episode 419: Reward=0.40, Avg10=-0.55
# Episode 420: Reward=-1.30, Avg10=-0.54
# Episode 421: Reward=0.80, Avg10=-0.34
# Episode 422: Reward=-1.30, Avg10=-0.33
# Episode 423: Reward=-0.50, Avg10=-0.48
# Episode 424: Reward=-4.80, Avg10=-1.05
# Episode 425: Reward=-1.40, Avg10=-1.11
# Episode 426: Reward=0.30, Avg10=-1.19
# Episode 427: Reward=-1.40, Avg10=-1.19
# Episode 428: Reward=-2.40, Avg10=-1.16
# Episode 429: Reward=-2.40, Avg10=-1.44
# Episode 430: Reward=-1.40, Avg10=-1.45
# Episode 431: Reward=-1.30, Avg10=-1.66
# Episode 432: Reward=-4.40, Avg10=-1.97
# Episode 433: Reward=-1.30, Avg10=-2.05
# Episode 434: Reward=-1.30, Avg10=-1.70
# Episode 435: Reward=-1.40, Avg10=-1.70
# Episode 436: Reward=-1.40, Avg10=-1.87
# Episode 437: Reward=-1.40, Avg10=-1.87
# Episode 438: Reward=-1.10, Avg10=-1.74
# Episode 439: Reward=-1.40, Avg10=-1.64
# Episode 440: Reward=0.90, Avg10=-1.41
# Episode 441: Reward=-1.90, Avg10=-1.47
# Episode 442: Reward=-1.90, Avg10=-1.22
# Episode 443: Reward=0.20, Avg10=-1.07
# Episode 444: Reward=0.80, Avg10=-0.86
# Episode 445: Reward=-1.40, Avg10=-0.86
# Episode 446: Reward=0.40, Avg10=-0.68
# Episode 447: Reward=-1.40, Avg10=-0.68
# Episode 448: Reward=1.00, Avg10=-0.47
# Episode 449: Reward=1.40, Avg10=-0.19
# Episode 450: Reward=2.20, Avg10=-0.06
# Episode 451: Reward=1.20, Avg10=0.25
# New best model saved + added to Self-play pool!
# Episode 452: Reward=-4.60, Avg10=-0.02
# Episode 453: Reward=-1.30, Avg10=-0.17
# Episode 454: Reward=0.90, Avg10=-0.16
# Episode 455: Reward=-1.30, Avg10=-0.15
# Episode 456: Reward=1.10, Avg10=-0.08
# Episode 457: Reward=0.70, Avg10=0.13
# Episode 458: Reward=-6.00, Avg10=-0.57
# Episode 459: Reward=-1.30, Avg10=-0.84
# Episode 460: Reward=-1.30, Avg10=-1.19
# Episode 461: Reward=-1.40, Avg10=-1.45
# Episode 462: Reward=-1.30, Avg10=-1.12
# Episode 463: Reward=-1.40, Avg10=-1.13
# Episode 464: Reward=0.50, Avg10=-1.17
# Episode 465: Reward=-0.50, Avg10=-1.09
# Episode 466: Reward=-1.40, Avg10=-1.34
# Episode 467: Reward=1.20, Avg10=-1.29
# Episode 468: Reward=-1.30, Avg10=-0.82
# Episode 469: Reward=-1.40, Avg10=-0.83
# Episode 470: Reward=-1.30, Avg10=-0.83
# Episode 471: Reward=1.30, Avg10=-0.56
# Episode 472: Reward=-1.40, Avg10=-0.57
# Episode 473: Reward=0.60, Avg10=-0.37
# Episode 474: Reward=-1.20, Avg10=-0.54
# Episode 475: Reward=0.80, Avg10=-0.41
# Episode 476: Reward=-1.40, Avg10=-0.41
# Episode 477: Reward=-1.40, Avg10=-0.67
# Episode 478: Reward=0.60, Avg10=-0.48
# Episode 479: Reward=-1.40, Avg10=-0.48
# Episode 480: Reward=-1.40, Avg10=-0.49
# Episode 481: Reward=-1.30, Avg10=-0.75
# Episode 482: Reward=-1.40, Avg10=-0.75
# Episode 483: Reward=-7.20, Avg10=-1.53
# Episode 484: Reward=1.20, Avg10=-1.29
# Episode 485: Reward=1.20, Avg10=-1.25
# Episode 486: Reward=0.60, Avg10=-1.05
# Episode 487: Reward=-2.90, Avg10=-1.20
# Episode 488: Reward=2.30, Avg10=-1.03
# Episode 489: Reward=-0.50, Avg10=-0.94
# Episode 490: Reward=-1.20, Avg10=-0.92
# Episode 491: Reward=0.60, Avg10=-0.73
# Episode 492: Reward=-1.40, Avg10=-0.73
# Episode 493: Reward=-1.40, Avg10=-0.15
# Episode 494: Reward=-1.40, Avg10=-0.41
# Episode 495: Reward=1.00, Avg10=-0.43
# Episode 496: Reward=-1.40, Avg10=-0.63
# Episode 497: Reward=-1.30, Avg10=-0.47
# Episode 498: Reward=1.50, Avg10=-0.55
# Episode 499: Reward=0.60, Avg10=-0.44
# Episode 500: Reward=-1.40, Avg10=-0.46
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep500.pth
# Episode 501: Reward=-0.30, Avg10=-0.55
# Episode 502: Reward=-3.00, Avg10=-0.71
# Episode 503: Reward=-1.40, Avg10=-0.71
# Episode 504: Reward=-1.40, Avg10=-0.71
# Episode 505: Reward=-1.40, Avg10=-0.95
# Episode 506: Reward=-1.40, Avg10=-0.95
# Episode 507: Reward=-0.10, Avg10=-0.83
# Episode 508: Reward=-2.20, Avg10=-1.20
# Episode 509: Reward=-0.80, Avg10=-1.34
# Episode 510: Reward=-0.10, Avg10=-1.21
# Episode 511: Reward=1.30, Avg10=-1.05
# Episode 512: Reward=-1.20, Avg10=-0.87
# Episode 513: Reward=-1.40, Avg10=-0.87
# Episode 514: Reward=-1.40, Avg10=-0.87
# Episode 515: Reward=1.10, Avg10=-0.62
# Episode 516: Reward=-1.40, Avg10=-0.62
# Episode 517: Reward=-1.40, Avg10=-0.75
# Episode 518: Reward=0.00, Avg10=-0.53
# Episode 519: Reward=-1.10, Avg10=-0.56
# Episode 520: Reward=-2.60, Avg10=-0.81
# Episode 521: Reward=-1.40, Avg10=-1.08
# Episode 522: Reward=-2.60, Avg10=-1.22
# Episode 523: Reward=1.30, Avg10=-0.95
# Episode 524: Reward=0.70, Avg10=-0.74
# Episode 525: Reward=-1.20, Avg10=-0.97
# Episode 526: Reward=-3.60, Avg10=-1.19
# Episode 527: Reward=-1.40, Avg10=-1.19
# Episode 528: Reward=-1.80, Avg10=-1.37
# Episode 529: Reward=-1.40, Avg10=-1.40
# Episode 530: Reward=-1.40, Avg10=-1.28
# Episode 531: Reward=-0.40, Avg10=-1.18
# Episode 532: Reward=-1.80, Avg10=-1.10
# Episode 533: Reward=1.40, Avg10=-1.09
# Episode 534: Reward=-1.40, Avg10=-1.30
# Episode 535: Reward=-1.40, Avg10=-1.32
# Episode 536: Reward=-2.50, Avg10=-1.21
# Episode 537: Reward=0.50, Avg10=-1.02
# Episode 538: Reward=0.70, Avg10=-0.77
# Episode 539: Reward=0.80, Avg10=-0.55
# Episode 540: Reward=1.20, Avg10=-0.29
# Episode 541: Reward=1.30, Avg10=-0.12
# Episode 542: Reward=-5.90, Avg10=-0.53
# Episode 543: Reward=-2.60, Avg10=-0.93
# Episode 544: Reward=-1.20, Avg10=-0.91
# Episode 545: Reward=-2.00, Avg10=-0.97
# Episode 546: Reward=-3.30, Avg10=-1.05
# Episode 547: Reward=-0.90, Avg10=-1.19
# Episode 548: Reward=-1.20, Avg10=-1.38
# Episode 549: Reward=-4.00, Avg10=-1.86
# Episode 550: Reward=0.50, Avg10=-1.93
# Episode 551: Reward=1.30, Avg10=-1.93
# Episode 552: Reward=-1.50, Avg10=-1.49
# Episode 553: Reward=-2.50, Avg10=-1.48
# Episode 554: Reward=-1.00, Avg10=-1.46
# Episode 555: Reward=-1.40, Avg10=-1.40
# Episode 556: Reward=0.90, Avg10=-0.98
# Episode 557: Reward=2.40, Avg10=-0.65
# Episode 558: Reward=-1.50, Avg10=-0.68
# Episode 559: Reward=-1.30, Avg10=-0.41
# Episode 560: Reward=-0.50, Avg10=-0.51
# Episode 561: Reward=-1.10, Avg10=-0.75
# Episode 562: Reward=-1.30, Avg10=-0.73
# Episode 563: Reward=-3.20, Avg10=-0.80
# Episode 564: Reward=-1.40, Avg10=-0.84
# Episode 565: Reward=1.20, Avg10=-0.58
# Episode 566: Reward=-2.40, Avg10=-0.91
# Episode 567: Reward=1.30, Avg10=-1.02
# Episode 568: Reward=-1.30, Avg10=-1.00
# Episode 569: Reward=-1.40, Avg10=-1.01
# Episode 570: Reward=-4.60, Avg10=-1.42
# Episode 571: Reward=-7.30, Avg10=-2.04
# Episode 572: Reward=-3.20, Avg10=-2.23
# Episode 573: Reward=-7.10, Avg10=-2.62
# Episode 574: Reward=-1.30, Avg10=-2.61
# Episode 575: Reward=-1.40, Avg10=-2.87
# Episode 576: Reward=-2.80, Avg10=-2.91
# Episode 577: Reward=1.20, Avg10=-2.92
# Episode 578: Reward=-1.30, Avg10=-2.92
# Episode 579: Reward=0.40, Avg10=-2.74
# Episode 580: Reward=-1.40, Avg10=-2.42
# Episode 581: Reward=1.10, Avg10=-1.58
# Episode 582: Reward=-0.80, Avg10=-1.34
# Episode 583: Reward=1.80, Avg10=-0.45
# Episode 584: Reward=-1.30, Avg10=-0.45
# Episode 585: Reward=-1.20, Avg10=-0.43
# Episode 586: Reward=-1.20, Avg10=-0.27
# Episode 587: Reward=-1.10, Avg10=-0.50
# Episode 588: Reward=-4.00, Avg10=-0.77
# Episode 589: Reward=-1.40, Avg10=-0.95
# Episode 590: Reward=-0.90, Avg10=-0.90
# Episode 591: Reward=-1.40, Avg10=-1.15
# Episode 592: Reward=0.50, Avg10=-1.02
# Episode 593: Reward=1.40, Avg10=-1.06
# Episode 594: Reward=-2.60, Avg10=-1.19
# Episode 595: Reward=-6.00, Avg10=-1.67
# Episode 596: Reward=-1.40, Avg10=-1.69
# Episode 597: Reward=-1.40, Avg10=-1.72
# Episode 598: Reward=-1.30, Avg10=-1.45
# Episode 599: Reward=1.40, Avg10=-1.17
# Episode 600: Reward=1.00, Avg10=-0.98
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep600.pth
# Episode 601: Reward=-1.30, Avg10=-0.97
# Episode 602: Reward=-1.30, Avg10=-1.15
# Episode 603: Reward=-0.90, Avg10=-1.38
# Episode 604: Reward=-1.30, Avg10=-1.25
# Episode 605: Reward=-1.40, Avg10=-0.79
# Episode 606: Reward=-1.40, Avg10=-0.79
# Episode 607: Reward=-1.40, Avg10=-0.79
# Episode 608: Reward=-1.40, Avg10=-0.80
# Episode 609: Reward=1.20, Avg10=-0.82
# Episode 610: Reward=0.50, Avg10=-0.87
# Episode 611: Reward=-1.40, Avg10=-0.88
# Episode 612: Reward=0.40, Avg10=-0.71
# Episode 613: Reward=-1.40, Avg10=-0.76
# Episode 614: Reward=-1.40, Avg10=-0.77
# Episode 615: Reward=0.00, Avg10=-0.63
# Episode 616: Reward=-1.40, Avg10=-0.63
# Episode 617: Reward=-2.00, Avg10=-0.69
# Episode 618: Reward=-1.40, Avg10=-0.69
# Episode 619: Reward=-10.80, Avg10=-1.89
# Episode 620: Reward=-1.30, Avg10=-2.07
# Episode 621: Reward=-3.00, Avg10=-2.23
# Episode 622: Reward=-1.40, Avg10=-2.41
# Episode 623: Reward=1.60, Avg10=-2.11
# Episode 624: Reward=-1.30, Avg10=-2.10
# Episode 625: Reward=0.90, Avg10=-2.01
# Episode 626: Reward=-1.40, Avg10=-2.01
# Episode 627: Reward=-1.60, Avg10=-1.97
# Episode 628: Reward=1.50, Avg10=-1.68
# Episode 629: Reward=-1.40, Avg10=-0.74
# Episode 630: Reward=-5.20, Avg10=-1.13
# Episode 631: Reward=-4.30, Avg10=-1.26
# Episode 632: Reward=-1.40, Avg10=-1.26
# Episode 633: Reward=-1.90, Avg10=-1.61
# Episode 634: Reward=-1.40, Avg10=-1.62
# Episode 635: Reward=0.40, Avg10=-1.67
# Episode 636: Reward=-2.00, Avg10=-1.73
# Episode 637: Reward=-1.20, Avg10=-1.69
# Episode 638: Reward=-1.50, Avg10=-1.99
# Episode 639: Reward=-1.00, Avg10=-1.95
# Episode 640: Reward=-1.50, Avg10=-1.58
# Episode 641: Reward=-0.90, Avg10=-1.24
# Episode 642: Reward=-6.50, Avg10=-1.75
# Episode 643: Reward=0.80, Avg10=-1.48
# Episode 644: Reward=-4.30, Avg10=-1.77
# Episode 645: Reward=-0.00, Avg10=-1.81
# Episode 646: Reward=-1.20, Avg10=-1.73
# Episode 647: Reward=-2.60, Avg10=-1.87
# Episode 648: Reward=-3.00, Avg10=-2.02
# Episode 649: Reward=-1.30, Avg10=-2.05
# Episode 650: Reward=0.30, Avg10=-1.87
# Episode 651: Reward=1.40, Avg10=-1.64
# Episode 652: Reward=-1.60, Avg10=-1.15
# Episode 653: Reward=-1.30, Avg10=-1.36
# Episode 654: Reward=-1.30, Avg10=-1.06
# Episode 655: Reward=-1.30, Avg10=-1.19
# Episode 656: Reward=-1.20, Avg10=-1.19
# Episode 657: Reward=1.20, Avg10=-0.81
# Episode 658: Reward=-2.30, Avg10=-0.74
# Episode 659: Reward=-0.60, Avg10=-0.67
# Episode 660: Reward=-1.40, Avg10=-0.84
# Episode 661: Reward=1.10, Avg10=-0.87
# Episode 662: Reward=-1.00, Avg10=-0.81
# Episode 663: Reward=-1.40, Avg10=-0.82
# Episode 664: Reward=0.30, Avg10=-0.66
# Episode 665: Reward=-2.10, Avg10=-0.74
# Episode 666: Reward=-1.40, Avg10=-0.76
# Episode 667: Reward=-2.70, Avg10=-1.15
# Episode 668: Reward=1.00, Avg10=-0.82
# Episode 669: Reward=1.90, Avg10=-0.57
# Episode 670: Reward=-2.50, Avg10=-0.68
# Episode 671: Reward=-4.70, Avg10=-1.26
# Episode 672: Reward=-2.70, Avg10=-1.43
# Episode 673: Reward=-5.60, Avg10=-1.85
# Episode 674: Reward=1.10, Avg10=-1.77
# Episode 675: Reward=-1.10, Avg10=-1.67
# Episode 676: Reward=-1.30, Avg10=-1.66
# Episode 677: Reward=-3.20, Avg10=-1.71
# Episode 678: Reward=-1.60, Avg10=-1.97
# Episode 679: Reward=-1.50, Avg10=-2.31
# Episode 680: Reward=-0.80, Avg10=-2.14
# Episode 681: Reward=-1.40, Avg10=-1.81
# Episode 682: Reward=-2.00, Avg10=-1.74
# Episode 683: Reward=-0.80, Avg10=-1.26
# Episode 684: Reward=1.30, Avg10=-1.24
# Episode 685: Reward=2.10, Avg10=-0.92
# Episode 686: Reward=-1.00, Avg10=-0.89
# Episode 687: Reward=-6.60, Avg10=-1.23
# Episode 688: Reward=-2.00, Avg10=-1.27
# Episode 689: Reward=-1.20, Avg10=-1.24
# Episode 690: Reward=-1.40, Avg10=-1.30
# Episode 691: Reward=-2.00, Avg10=-1.36
# Episode 692: Reward=2.10, Avg10=-0.95
# Episode 693: Reward=-2.10, Avg10=-1.08
# Episode 694: Reward=1.20, Avg10=-1.09
# Episode 695: Reward=1.20, Avg10=-1.18
# Episode 696: Reward=-3.70, Avg10=-1.45
# Episode 697: Reward=-2.90, Avg10=-1.08
# Episode 698: Reward=-1.40, Avg10=-1.02
# Episode 699: Reward=-1.20, Avg10=-1.02
# Episode 700: Reward=-1.50, Avg10=-1.03
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep700.pth
# Episode 701: Reward=-1.50, Avg10=-0.98
# Episode 702: Reward=0.90, Avg10=-1.10
# Episode 703: Reward=-1.50, Avg10=-1.04
# Episode 704: Reward=0.80, Avg10=-1.08
# Episode 705: Reward=-5.00, Avg10=-1.70
# Episode 706: Reward=1.40, Avg10=-1.19
# Episode 707: Reward=0.60, Avg10=-0.84
# Episode 708: Reward=1.20, Avg10=-0.58
# Episode 709: Reward=-1.20, Avg10=-0.58
# Episode 710: Reward=-3.80, Avg10=-0.81
# Episode 711: Reward=-1.30, Avg10=-0.79
# Episode 712: Reward=0.10, Avg10=-0.87
# Episode 713: Reward=-1.30, Avg10=-0.85
# Episode 714: Reward=-1.40, Avg10=-1.07
# Episode 715: Reward=-1.30, Avg10=-0.70
# Episode 716: Reward=-2.20, Avg10=-1.06
# Episode 717: Reward=-1.20, Avg10=-1.24
# Episode 718: Reward=-2.30, Avg10=-1.59
# Episode 719: Reward=0.80, Avg10=-1.39
# Episode 720: Reward=-1.30, Avg10=-1.14
# Episode 721: Reward=-1.40, Avg10=-1.15
# Episode 722: Reward=-1.30, Avg10=-1.29
# Episode 723: Reward=-1.40, Avg10=-1.30
# Episode 724: Reward=-1.50, Avg10=-1.31
# Episode 725: Reward=-1.00, Avg10=-1.28
# Episode 726: Reward=0.20, Avg10=-1.04
# Episode 727: Reward=-1.30, Avg10=-1.05
# Episode 728: Reward=-1.30, Avg10=-0.95
# Episode 729: Reward=-1.40, Avg10=-1.17
# Episode 730: Reward=-1.40, Avg10=-1.18
# Episode 731: Reward=-0.80, Avg10=-1.12
# Episode 732: Reward=-0.10, Avg10=-1.00
# Episode 733: Reward=-1.40, Avg10=-1.00
# Episode 734: Reward=-1.30, Avg10=-0.98
# Episode 735: Reward=-1.40, Avg10=-1.02
# Episode 736: Reward=-1.20, Avg10=-1.16
# Episode 737: Reward=-1.30, Avg10=-1.16
# Episode 738: Reward=-1.20, Avg10=-1.15
# Episode 739: Reward=-8.40, Avg10=-1.85
# Episode 740: Reward=1.60, Avg10=-1.55
# Episode 741: Reward=-0.70, Avg10=-1.54
# Episode 742: Reward=-1.70, Avg10=-1.70
# Episode 743: Reward=-1.20, Avg10=-1.68
# Episode 744: Reward=-1.70, Avg10=-1.72
# Episode 745: Reward=-2.00, Avg10=-1.78
# Episode 746: Reward=0.90, Avg10=-1.57
# Episode 747: Reward=-1.80, Avg10=-1.62
# Episode 748: Reward=-1.30, Avg10=-1.63
# Episode 749: Reward=0.00, Avg10=-0.79
# Episode 750: Reward=-1.50, Avg10=-1.10
# Episode 751: Reward=-2.80, Avg10=-1.31
# Episode 752: Reward=-1.10, Avg10=-1.25
# Episode 753: Reward=2.00, Avg10=-0.93
# Episode 754: Reward=2.80, Avg10=-0.48
# Episode 755: Reward=1.30, Avg10=-0.15
# Episode 756: Reward=1.60, Avg10=-0.08
# Episode 757: Reward=-0.20, Avg10=0.08
# Episode 758: Reward=-2.30, Avg10=-0.02
# Episode 759: Reward=-3.20, Avg10=-0.34
# Episode 760: Reward=-2.30, Avg10=-0.42
# Episode 761: Reward=-4.70, Avg10=-0.61
# Episode 762: Reward=-1.40, Avg10=-0.64
# Episode 763: Reward=1.10, Avg10=-0.73
# Episode 764: Reward=-1.30, Avg10=-1.14
# Episode 765: Reward=1.10, Avg10=-1.16
# Episode 766: Reward=-2.10, Avg10=-1.53
# Episode 767: Reward=-1.40, Avg10=-1.65
# Episode 768: Reward=1.40, Avg10=-1.28
# Episode 769: Reward=-0.60, Avg10=-1.02
# Episode 770: Reward=-1.30, Avg10=-0.92
# Episode 771: Reward=-1.40, Avg10=-0.59
# Episode 772: Reward=-1.30, Avg10=-0.58
# Episode 773: Reward=-1.30, Avg10=-0.82
# Episode 774: Reward=0.40, Avg10=-0.65
# Episode 775: Reward=-2.10, Avg10=-0.97
# Episode 776: Reward=1.00, Avg10=-0.66
# Episode 777: Reward=1.10, Avg10=-0.41
# Episode 778: Reward=-2.30, Avg10=-0.78
# Episode 779: Reward=-1.40, Avg10=-0.86
# Episode 780: Reward=-2.20, Avg10=-0.95
# Episode 781: Reward=-1.60, Avg10=-0.97
# Episode 782: Reward=0.90, Avg10=-0.75
# Episode 783: Reward=1.10, Avg10=-0.51
# Episode 784: Reward=-3.30, Avg10=-0.88
# Episode 785: Reward=1.90, Avg10=-0.48
# Episode 786: Reward=0.50, Avg10=-0.53
# Episode 787: Reward=-1.40, Avg10=-0.78
# Episode 788: Reward=1.60, Avg10=-0.39
# Episode 789: Reward=-7.20, Avg10=-0.97
# Episode 790: Reward=-3.40, Avg10=-1.09
# Episode 791: Reward=0.00, Avg10=-0.93
# Episode 792: Reward=1.30, Avg10=-0.89
# Episode 793: Reward=1.60, Avg10=-0.84
# Episode 794: Reward=-1.30, Avg10=-0.64
# Episode 795: Reward=0.50, Avg10=-0.78
# Episode 796: Reward=1.40, Avg10=-0.69
# Episode 797: Reward=-2.20, Avg10=-0.77
# Episode 798: Reward=0.60, Avg10=-0.87
# Episode 799: Reward=-0.90, Avg10=-0.24
# Episode 800: Reward=-1.40, Avg10=-0.04
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep800.pth
# Episode 801: Reward=1.00, Avg10=0.06
# Episode 802: Reward=-5.20, Avg10=-0.59
# Episode 803: Reward=0.40, Avg10=-0.71
# Episode 804: Reward=-1.90, Avg10=-0.77
# Episode 805: Reward=-2.30, Avg10=-1.05
# Episode 806: Reward=-3.80, Avg10=-1.57
# Episode 807: Reward=0.80, Avg10=-1.27
# Episode 808: Reward=-2.80, Avg10=-1.61
# Episode 809: Reward=-3.70, Avg10=-1.89
# Episode 810: Reward=-2.20, Avg10=-1.97
# Episode 811: Reward=-1.40, Avg10=-2.21
# Episode 812: Reward=-2.60, Avg10=-1.95
# Episode 813: Reward=-1.70, Avg10=-2.16
# Episode 814: Reward=-2.00, Avg10=-2.17
# Episode 815: Reward=-1.40, Avg10=-2.08
# Episode 816: Reward=-0.10, Avg10=-1.71
# Episode 817: Reward=0.90, Avg10=-1.70
# Episode 818: Reward=-1.00, Avg10=-1.52
# Episode 819: Reward=-3.90, Avg10=-1.54
# Episode 820: Reward=-2.50, Avg10=-1.57
# Episode 821: Reward=-2.10, Avg10=-1.64
# Episode 822: Reward=-0.20, Avg10=-1.40
# Episode 823: Reward=0.20, Avg10=-1.21
# Episode 824: Reward=0.40, Avg10=-0.97
# Episode 825: Reward=-1.70, Avg10=-1.00
# Episode 826: Reward=-1.80, Avg10=-1.17
# Episode 827: Reward=-1.90, Avg10=-1.45
# Episode 828: Reward=-3.00, Avg10=-1.65
# Episode 829: Reward=0.70, Avg10=-1.19
# Episode 830: Reward=-3.60, Avg10=-1.30
# Episode 831: Reward=-6.60, Avg10=-1.75
# Episode 832: Reward=0.30, Avg10=-1.70
# Episode 833: Reward=0.80, Avg10=-1.64
# Episode 834: Reward=1.60, Avg10=-1.52
# Episode 835: Reward=0.80, Avg10=-1.27
# Episode 836: Reward=-1.10, Avg10=-1.20
# Episode 837: Reward=1.40, Avg10=-0.87
# Episode 838: Reward=-2.50, Avg10=-0.82
# Episode 839: Reward=0.10, Avg10=-0.88
# Episode 840: Reward=-3.00, Avg10=-0.82
# Episode 841: Reward=-1.00, Avg10=-0.26
# Episode 842: Reward=0.60, Avg10=-0.23
# Episode 843: Reward=-0.80, Avg10=-0.39
# Episode 844: Reward=1.30, Avg10=-0.42
# Episode 845: Reward=1.50, Avg10=-0.35
# Episode 846: Reward=1.40, Avg10=-0.10
# Episode 847: Reward=-1.30, Avg10=-0.37
# Episode 848: Reward=1.30, Avg10=0.01
# Episode 849: Reward=-1.90, Avg10=-0.19
# Episode 850: Reward=-1.70, Avg10=-0.06
# Episode 851: Reward=0.60, Avg10=0.10
# Episode 852: Reward=1.30, Avg10=0.17
# Episode 853: Reward=1.30, Avg10=0.38
# New best model saved + added to Self-play pool!
# Episode 854: Reward=0.20, Avg10=0.27
# Episode 855: Reward=-1.30, Avg10=-0.01
# Episode 856: Reward=1.20, Avg10=-0.03
# Episode 857: Reward=1.50, Avg10=0.25
# Episode 858: Reward=-1.20, Avg10=0.00
# Episode 859: Reward=0.30, Avg10=0.22
# Episode 860: Reward=-1.00, Avg10=0.29
# Episode 861: Reward=1.30, Avg10=0.36
# Episode 862: Reward=1.30, Avg10=0.36
# Episode 863: Reward=-1.10, Avg10=0.12
# Episode 864: Reward=-1.40, Avg10=-0.04
# Episode 865: Reward=1.30, Avg10=0.22
# Episode 866: Reward=-1.10, Avg10=-0.01
# Episode 867: Reward=1.10, Avg10=-0.05
# Episode 868: Reward=-1.30, Avg10=-0.06
# Episode 869: Reward=0.40, Avg10=-0.05
# Episode 870: Reward=-1.30, Avg10=-0.08
# Episode 871: Reward=-2.50, Avg10=-0.46
# Episode 872: Reward=-1.00, Avg10=-0.69
# Episode 873: Reward=-1.80, Avg10=-0.76
# Episode 874: Reward=-1.40, Avg10=-0.76
# Episode 875: Reward=-4.90, Avg10=-1.38
# Episode 876: Reward=-1.50, Avg10=-1.42
# Episode 877: Reward=-3.30, Avg10=-1.86
# Episode 878: Reward=-1.90, Avg10=-1.92
# Episode 879: Reward=-1.80, Avg10=-2.14
# Episode 880: Reward=-1.60, Avg10=-2.17
# Episode 881: Reward=-9.50, Avg10=-2.87
# Episode 882: Reward=-1.80, Avg10=-2.95
# Episode 883: Reward=0.20, Avg10=-2.75
# Episode 884: Reward=1.00, Avg10=-2.51
# Episode 885: Reward=-1.80, Avg10=-2.20
# Episode 886: Reward=-0.80, Avg10=-2.13
# Episode 887: Reward=-3.10, Avg10=-2.11
# Episode 888: Reward=1.00, Avg10=-1.82
# Episode 889: Reward=1.30, Avg10=-1.51
# Episode 890: Reward=-1.50, Avg10=-1.50
# Episode 891: Reward=1.30, Avg10=-0.42
# Episode 892: Reward=-0.90, Avg10=-0.33
# Episode 893: Reward=-1.20, Avg10=-0.47
# Episode 894: Reward=-3.50, Avg10=-0.92
# Episode 895: Reward=1.00, Avg10=-0.64
# Episode 896: Reward=1.10, Avg10=-0.45
# Episode 897: Reward=-4.50, Avg10=-0.59
# Episode 898: Reward=-3.10, Avg10=-1.00
# Episode 899: Reward=-4.80, Avg10=-1.61
# Episode 900: Reward=-2.80, Avg10=-1.74
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep900.pth
# Episode 901: Reward=1.20, Avg10=-1.75
# Episode 902: Reward=-1.40, Avg10=-1.80
# Episode 903: Reward=-2.60, Avg10=-1.94
# Episode 904: Reward=-0.10, Avg10=-1.60
# Episode 905: Reward=-3.10, Avg10=-2.01
# Episode 906: Reward=-2.50, Avg10=-2.37
# Episode 907: Reward=0.70, Avg10=-1.85
# Episode 908: Reward=-1.20, Avg10=-1.66
# Episode 909: Reward=-2.40, Avg10=-1.42
# Episode 910: Reward=1.20, Avg10=-1.02
# Episode 911: Reward=-0.60, Avg10=-1.20
# Episode 912: Reward=-6.50, Avg10=-1.71
# Episode 913: Reward=2.20, Avg10=-1.23
# Episode 914: Reward=-1.60, Avg10=-1.38
# Episode 915: Reward=-0.70, Avg10=-1.14
# Episode 916: Reward=-1.70, Avg10=-1.06
# Episode 917: Reward=0.70, Avg10=-1.06
# Episode 918: Reward=0.10, Avg10=-0.93
# Episode 919: Reward=-2.30, Avg10=-0.92
# Episode 920: Reward=-0.60, Avg10=-1.10
# Episode 921: Reward=-1.70, Avg10=-1.21
# Episode 922: Reward=1.10, Avg10=-0.45
# Episode 923: Reward=-3.30, Avg10=-1.00
# Episode 924: Reward=-5.60, Avg10=-1.40
# Episode 925: Reward=-1.40, Avg10=-1.47
# Episode 926: Reward=1.50, Avg10=-1.15
# Episode 927: Reward=-1.20, Avg10=-1.34
# Episode 928: Reward=1.30, Avg10=-1.22
# Episode 929: Reward=1.20, Avg10=-0.87
# Episode 930: Reward=-2.30, Avg10=-1.04
# Episode 931: Reward=-1.10, Avg10=-0.98
# Episode 932: Reward=-1.20, Avg10=-1.21
# Episode 933: Reward=-2.60, Avg10=-1.14
# Episode 934: Reward=-1.40, Avg10=-0.72
# Episode 935: Reward=-1.20, Avg10=-0.70
# Episode 936: Reward=-1.50, Avg10=-1.00
# Episode 937: Reward=1.10, Avg10=-0.77
# Episode 938: Reward=-1.20, Avg10=-1.02
# Episode 939: Reward=1.00, Avg10=-1.04
# Episode 940: Reward=1.30, Avg10=-0.68
# Episode 941: Reward=1.50, Avg10=-0.42
# Episode 942: Reward=-2.40, Avg10=-0.54
# Episode 943: Reward=-1.50, Avg10=-0.43
# Episode 944: Reward=-6.30, Avg10=-0.92
# Episode 945: Reward=-0.60, Avg10=-0.86
# Episode 946: Reward=-1.20, Avg10=-0.83
# Episode 947: Reward=1.20, Avg10=-0.82
# Episode 948: Reward=1.30, Avg10=-0.57
# Episode 949: Reward=0.00, Avg10=-0.67
# Episode 950: Reward=0.30, Avg10=-0.77
# Episode 951: Reward=1.50, Avg10=-0.77
# Episode 952: Reward=-1.60, Avg10=-0.69
# Episode 953: Reward=0.20, Avg10=-0.52
# Episode 954: Reward=-1.60, Avg10=-0.05
# Episode 955: Reward=-1.40, Avg10=-0.13
# Episode 956: Reward=0.50, Avg10=0.04
# Episode 957: Reward=-0.70, Avg10=-0.15
# Episode 958: Reward=-1.20, Avg10=-0.40
# Episode 959: Reward=-2.70, Avg10=-0.67
# Episode 960: Reward=0.60, Avg10=-0.64
# Episode 961: Reward=0.20, Avg10=-0.77
# Episode 962: Reward=-4.20, Avg10=-1.03
# Episode 963: Reward=-1.60, Avg10=-1.21
# Episode 964: Reward=-1.60, Avg10=-1.21
# Episode 965: Reward=-0.90, Avg10=-1.16
# Episode 966: Reward=0.40, Avg10=-1.17
# Episode 967: Reward=-1.60, Avg10=-1.26
# Episode 968: Reward=-2.20, Avg10=-1.36
# Episode 969: Reward=-1.40, Avg10=-1.23
# Episode 970: Reward=-3.10, Avg10=-1.60
# Episode 971: Reward=-1.10, Avg10=-1.73
# Episode 972: Reward=-1.00, Avg10=-1.41
# Episode 973: Reward=-6.20, Avg10=-1.87
# Episode 974: Reward=-1.40, Avg10=-1.85
# Episode 975: Reward=-0.30, Avg10=-1.79
# Episode 976: Reward=-3.40, Avg10=-2.17
# Episode 977: Reward=-4.10, Avg10=-2.42
# Episode 978: Reward=-8.20, Avg10=-3.02
# Episode 979: Reward=-1.20, Avg10=-3.00
# Episode 980: Reward=-1.90, Avg10=-2.88
# Episode 981: Reward=1.80, Avg10=-2.59
# Episode 982: Reward=-1.20, Avg10=-2.61
# Episode 983: Reward=-2.00, Avg10=-2.19
# Episode 984: Reward=-2.80, Avg10=-2.33
# Episode 985: Reward=-3.70, Avg10=-2.67
# Episode 986: Reward=-2.00, Avg10=-2.53
# Episode 987: Reward=-3.50, Avg10=-2.47
# Episode 988: Reward=-1.00, Avg10=-1.75
# Episode 989: Reward=1.90, Avg10=-1.44
# Episode 990: Reward=-3.40, Avg10=-1.59
# Episode 991: Reward=-1.60, Avg10=-1.93
# Episode 992: Reward=1.30, Avg10=-1.68
# Episode 993: Reward=-1.30, Avg10=-1.61
# Episode 994: Reward=-3.70, Avg10=-1.70
# Episode 995: Reward=-2.90, Avg10=-1.62
# Episode 996: Reward=-0.60, Avg10=-1.48
# Episode 997: Reward=-2.80, Avg10=-1.41
# Episode 998: Reward=1.20, Avg10=-1.19
# Episode 999: Reward=-1.40, Avg10=-1.52
# Episode 1000: Reward=-1.20, Avg10=-1.30
#  Saved checkpoint runs\connect4_20251123_042650\checkpoint_ep1000.pth
